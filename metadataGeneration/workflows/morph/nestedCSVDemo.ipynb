# %% [markdown]
# # Nested CSV
#
# Simple test exploring how to map nested CSV documents into Pandas
#
# The question is how would this work with RML[Morph].
# The exploded dataframe, if that is the correct route, would end up with a large number of extra rows.
# This would mean that the RML process, as it moves through the rows, would generate many duplicate triples.
#
# This is fine since duplicate triples are rather easy to process out.  Either through string matches or
# simply routing the data through a triplestore like Oxigraph, which will simply absorb the duplicates into
# single representations.  This means we are generating extra triples we don't need, but it is not a heavy
# computational burden and is likely an easier route than an alternative.
#
# Note, an _optimized_ approach would be to generate a subset of columns into a new dataframe and
# then generate triples from that and merge them with the triples from the main frame that ignores
# the nested value columns.   For example, like the df_subset example below.

# %%
import pandas as pd
import json

# %%
df = pd.read_csv("../inputs/GDSC_metadata.csv")

# %%
df
# Out:
#       ID                                              Title  \
# 0    1.0  Miami-Dade Home Owner's Loan Corporation (HOLC...
# 1    2.0                         2019 Florida Census Tracts
# 2    3.0  2019 Miami-Dade ACS 5 Year Estimates - Tract L...
# 3    4.0  2019 Florida ACS 5 Year Estimates - Tract Leve...
# 4    5.0               2020 Florida Census Tracts - Florida
# ..   ...                                                ...
# 143  NaN                                                NaN
# 144  NaN                                                NaN
# 145  NaN                                                NaN
# 146  NaN                                                NaN
# 147  NaN                                                NaN
#
#                                                Creator  \
# 0     University of Richmond's Digital Scholarship Lab
# 1    Department of Commerce|U.S. Census Bureau|Geog...
# 2            Department of Commerce|U.S. Census Bureau
# 3            Department of Commerce|U.S. Census Bureau
# 4    Department of Commerce|U.S. Census Bureau|Geog...
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#                                                    Url  DOI  \
# 0    https://services.arcgis.com/jIL9msH9OI208GCb/a...  NaN
# 1    https://www.census.gov/geographies/mapping-fil...  NaN
# 2    https://www.census.gov/data/developers/data-se...  NaN
# 3    https://www.census.gov/data/developers/data-se...  NaN
# 4    https://www.census.gov/geographies/mapping-fil...  NaN
# ..                                                 ...  ...
# 143                                                NaN  NaN
# 144                                                NaN  NaN
# 145                                                NaN  NaN
# 146                                                NaN  NaN
# 147                                                NaN  NaN
#
#                                              Publisher         Rights  \
# 0     University of Richmond's Digital Scholarship Lab  Public Domain
# 1    Department of Commerce|U.S. Census Bureau|Geog...  Public Domain
# 2            Department of Commerce|U.S. Census Bureau  Public Domain
# 3            Department of Commerce|U.S. Census Bureau  Public Domain
# 4    Department of Commerce|U.S. Census Bureau|Geog...  Public Domain
# ..                                                 ...            ...
# 143                                                NaN            NaN
# 144                                                NaN            NaN
# 145                                                NaN            NaN
# 146                                                NaN            NaN
# 147                                                NaN            NaN
#
#                                                License  \
# 0                                                  NaN
# 1    This Software was created by U.S. Government e...
# 2    This Software was created by U.S. Government e...
# 3    This Software was created by U.S. Government e...
# 4    This Software was created by U.S. Government e...
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#                                           Restrictions               Coverage  \
# 0    Use items owned by Esri in ArcGIS Online in co...          United States
# 1                                                  NaN  United States|Florida
# 2                                                  NaN  United States|Florida
# 3                                                  NaN  United States|Florida
# 4                                                  NaN  United States|Florida
# ..                                                 ...                    ...
# 143                                                NaN                    NaN
# 144                                                NaN                    NaN
# 145                                                NaN                    NaN
# 146                                                NaN                    NaN
# 147                                                NaN                    NaN
#
#      ... Index Fields Bash ETL SQL Transform Last Updated Update Frequency  \
# 0    ...           --      TBD           TBD   2021-08-17            Never
# 1    ...           --      TBD           TBD   2021-09-22            Never
# 2    ...           --      TBD           TBD   2021-06-02            Never
# 3    ...           --      TBD           TBD   2022-11-22            Never
# 4    ...           --      TBD           TBD   2021-09-22            Never
# ..   ...          ...      ...           ...          ...              ...
# 143  ...          NaN      NaN           NaN          NaN              NaN
# 144  ...          NaN      NaN           NaN          NaN              NaN
# 145  ...          NaN      NaN           NaN          NaN              NaN
# 146  ...          NaN      NaN           NaN          NaN              NaN
# 147  ...          NaN      NaN           NaN          NaN              NaN
#
#     Last Accessed                                            Columns  \
# 0              --  OBJECTID|HOLC_grade|city|HOLC|Code|ST |CitySta...
# 1              --  STATEFP(string,2)|COUNTYFP(string,3)|TRACTCE(s...
# 2              --  https://api.census.gov/data/2019/acs/acs5/vari...
# 3              --  https://api.census.gov/data/2019/acs/acs5/vari...
# 4              --  STATEFP(string,2)|COUNTYFP(string,3)|TRACTCE(s...
# ..            ...                                                ...
# 143           NaN                                                NaN
# 144           NaN                                                NaN
# 145           NaN                                                NaN
# 146           NaN                                                NaN
# 147           NaN                                                NaN
#
#                                      ETL Documentation  \
# 0    Direct download as ESRI json from ESRI service...
# 1                         ogr2ogr shapefile to postGIS
# 2    The custom function acs_customgregate is given...
# 3    The custom function acs_customgregate is given...
# 4                         ogr2ogr shapefile to postGIS
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#                                                  Notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2    please use this as a template for all ACS esti...
# 3                  update using 2019 DVMT ACS as model
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#                                                   TODO
# 0    update to reflect Miami only\ninclude other ci...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
# [148 rows x 66 columns]

# %%
# just grab a few columns to work with that has an example nested column to work with
columns_subset = ['ID', 'Title', 'Rights', 'Coverage']
df_subset = df[columns_subset]

# %%
df_subset.head(10)
# Out:
#      ID                                              Title         Rights  \
# 0   1.0  Miami-Dade Home Owner's Loan Corporation (HOLC...  Public Domain
# 1   2.0                         2019 Florida Census Tracts  Public Domain
# 2   3.0  2019 Miami-Dade ACS 5 Year Estimates - Tract L...  Public Domain
# 3   4.0  2019 Florida ACS 5 Year Estimates - Tract Leve...  Public Domain
# 4   5.0               2020 Florida Census Tracts - Florida  Public Domain
# 5   6.0  2020 Florida ACS 5 Year Estimates - Tract Leve...  Public Domain
# 6   7.0  2020 Florida ACS 5 Year Estimates - Tract Leve...  Public Domain
# 7   8.0               2021 Florida Census Tracts - Florida  Public Domain
# 8   9.0  2021 Miami-Dade ACS 5 Year Estimates - Tract L...  Public Domain
# 9  10.0  2021 Florida ACS 5 Year Estimates - Block Grou...  Public Domain
#
#                                   Coverage
# 0                            United States
# 1                    United States|Florida
# 2                    United States|Florida
# 3                    United States|Florida
# 4                    United States|Florida
# 5                    United States|Florida
# 6                    United States|Florida
# 7                    United States|Florida
# 8  United States|Florida|Miami-Dade County
# 9                    United States|Florida

# %%
df_subset['Coverage2'] = df_subset['Coverage'].str.split('|')
df_sub_explode= df_subset.explode('Coverage2')
# Out:
# /tmp/ipykernel_2461263/2160769529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['Coverage2'] = df_subset['Coverage'].str.split('|')

# %%
df_sub_explode.head(10)
# Out:
#     ID                                              Title         Rights  \
# 0  1.0  Miami-Dade Home Owner's Loan Corporation (HOLC...  Public Domain
# 1  2.0                         2019 Florida Census Tracts  Public Domain
# 1  2.0                         2019 Florida Census Tracts  Public Domain
# 2  3.0  2019 Miami-Dade ACS 5 Year Estimates - Tract L...  Public Domain
# 2  3.0  2019 Miami-Dade ACS 5 Year Estimates - Tract L...  Public Domain
# 3  4.0  2019 Florida ACS 5 Year Estimates - Tract Leve...  Public Domain
# 3  4.0  2019 Florida ACS 5 Year Estimates - Tract Leve...  Public Domain
# 4  5.0               2020 Florida Census Tracts - Florida  Public Domain
# 4  5.0               2020 Florida Census Tracts - Florida  Public Domain
# 5  6.0  2020 Florida ACS 5 Year Estimates - Tract Leve...  Public Domain
#
#                 Coverage      Coverage2
# 0          United States  United States
# 1  United States|Florida  United States
# 1  United States|Florida        Florida
# 2  United States|Florida  United States
# 2  United States|Florida        Florida
# 3  United States|Florida  United States
# 3  United States|Florida        Florida
# 4  United States|Florida  United States
# 4  United States|Florida        Florida
# 5  United States|Florida  United States

# %% [markdown]
# ## Example for JSON with normalize and meta

# %%
# with open('books.json') as f:
#     data = json.load(f)

data = json.loads(j)

# Use pd.json_normalize to convert the JSON to a DataFrame
df = pd.json_normalize(data['books'], meta=['title', ['author', 'first_name'], ['author', 'last_name'], ['publisher', 'name'], ['publisher', 'location']])

# Rename the columns for clarity
df.columns = ['Title', 'Author_First_Name', 'Author_Last_Name', 'Publisher_Name', 'Publisher_Location']

# Display the DataFrame
df.head()
