# %% [markdown]
# # CSV to JSON-LD via Morph
#
# ref: https://github.com/morph-kgc/morph-kgc/tree/main/examples

# %% [markdown]
# ## Imports

# %%
import morph_kgc
import pandas as pd
import json
import jbutils
import pyoxigraph

# %%
df = pd.read_csv("../inputs/GDSC_metadata.csv")

# %%
print(df.columns.values)
# Out:
# ['ID' 'Title' 'Creator' 'Url' 'DOI' 'Publisher' 'Rights' 'License'
#  'Restrictions' 'Coverage' 'Relations' 'Type' 'Date' 'Description'
#  'Provenance' 'Subject' 'Language' 'Structure' 'Geometry' 'Bands'
#  'Pixel Dimension' 'EPSG' 'Scale' 'Extent' 'Lineage' 'Process Step'
#  'Processor' 'Point of Contact' 'Data Level' 'Label' 'Values' 'Attributes'
#  'Color Ramp' 'Tile Zoom Levels' 'Collections' 'Analytic Function'
#  'Analytic EPSG' 'Thumbnail' 'Service Definition' 'Sponsor' 'Status'
#  'Rights Statement' 'Disclaimer' 'Service' 'Source' 'Parameters'
#  'File Name' 'Extension' 'Download' 'Table Name' 'Format' 'Dependency'
#  'Custom ETL' 'Custom Parameters' 'up' 'podID' 'Index Fields' 'Bash ETL'
#  'SQL Transform' 'Last Updated' 'Update Frequency' 'Last Accessed'
#  'Columns' 'ETL Documentation' 'Notes' 'TODO']

# %%
df.head(10)
# Out:
#      ID                                              Title  \
# 0   1.0  Miami-Dade Home Owner's Loan Corporation (HOLC...
# 1   2.0                         2019 Florida Census Tracts
# 2   3.0  2019 Miami-Dade ACS 5 Year Estimates - Tract L...
# 3   4.0  2019 Florida ACS 5 Year Estimates - Tract Leve...
# 4   5.0               2020 Florida Census Tracts - Florida
# 5   6.0  2020 Florida ACS 5 Year Estimates - Tract Leve...
# 6   7.0  2020 Florida ACS 5 Year Estimates - Tract Leve...
# 7   8.0               2021 Florida Census Tracts - Florida
# 8   9.0  2021 Miami-Dade ACS 5 Year Estimates - Tract L...
# 9  10.0  2021 Florida ACS 5 Year Estimates - Block Grou...
#
#                                              Creator  \
# 0   University of Richmond's Digital Scholarship Lab
# 1  Department of Commerce|U.S. Census Bureau|Geog...
# 2          Department of Commerce|U.S. Census Bureau
# 3          Department of Commerce|U.S. Census Bureau
# 4  Department of Commerce|U.S. Census Bureau|Geog...
# 5          Department of Commerce|U.S. Census Bureau
# 6          Department of Commerce|U.S. Census Bureau
# 7  Department of Commerce|U.S. Census Bureau|Geog...
# 8          Department of Commerce|U.S. Census Bureau
# 9          Department of Commerce|U.S. Census Bureau
#
#                                                  Url  DOI  \
# 0  https://services.arcgis.com/jIL9msH9OI208GCb/a...  NaN
# 1  https://www.census.gov/geographies/mapping-fil...  NaN
# 2  https://www.census.gov/data/developers/data-se...  NaN
# 3  https://www.census.gov/data/developers/data-se...  NaN
# 4  https://www.census.gov/geographies/mapping-fil...  NaN
# 5  https://www.census.gov/data/developers/data-se...  NaN
# 6  https://www.census.gov/data/developers/data-se...  NaN
# 7  https://www.census.gov/geographies/mapping-fil...  NaN
# 8  https://www.census.gov/data/developers/data-se...  NaN
# 9  https://www.census.gov/data/developers/data-se...  NaN
#
#                                            Publisher         Rights  \
# 0   University of Richmond's Digital Scholarship Lab  Public Domain
# 1  Department of Commerce|U.S. Census Bureau|Geog...  Public Domain
# 2          Department of Commerce|U.S. Census Bureau  Public Domain
# 3          Department of Commerce|U.S. Census Bureau  Public Domain
# 4  Department of Commerce|U.S. Census Bureau|Geog...  Public Domain
# 5          Department of Commerce|U.S. Census Bureau  Public Domain
# 6          Department of Commerce|U.S. Census Bureau  Public Domain
# 7  Department of Commerce|U.S. Census Bureau|Geog...  Public Domain
# 8          Department of Commerce|U.S. Census Bureau  Public Domain
# 9          Department of Commerce|U.S. Census Bureau  Public Domain
#
#                                              License  \
# 0                                                NaN
# 1  This Software was created by U.S. Government e...
# 2  This Software was created by U.S. Government e...
# 3  This Software was created by U.S. Government e...
# 4  This Software was created by U.S. Government e...
# 5  This Software was created by U.S. Government e...
# 6  This Software was created by U.S. Government e...
# 7  This Software was created by U.S. Government e...
# 8  This Software was created by U.S. Government e...
# 9  This Software was created by U.S. Government e...
#
#                                         Restrictions  \
# 0  Use items owned by Esri in ArcGIS Online in co...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                   Coverage  ... Index Fields Bash ETL  \
# 0                            United States  ...           --      TBD
# 1                    United States|Florida  ...           --      TBD
# 2                    United States|Florida  ...           --      TBD
# 3                    United States|Florida  ...           --      TBD
# 4                    United States|Florida  ...           --      TBD
# 5                    United States|Florida  ...           --      TBD
# 6                    United States|Florida  ...           --      TBD
# 7                    United States|Florida  ...           --      TBD
# 8  United States|Florida|Miami-Dade County  ...           --      TBD
# 9                    United States|Florida  ...           --      TBD
#
#   SQL Transform Last Updated Update Frequency Last Accessed  \
# 0           TBD   2021-08-17            Never            --
# 1           TBD   2021-09-22            Never            --
# 2           TBD   2021-06-02            Never            --
# 3           TBD   2022-11-22            Never            --
# 4           TBD   2021-09-22            Never            --
# 5           TBD   2021-06-02            Never            --
# 6           TBD   2022-11-22            Never            --
# 7           TBD   2021-09-22            Never            --
# 8           TBD   2021-06-02            Never            --
# 9           TBD   2021-06-02            Never            --
#
#                                              Columns  \
# 0  OBJECTID|HOLC_grade|city|HOLC|Code|ST |CitySta...
# 1  STATEFP(string,2)|COUNTYFP(string,3)|TRACTCE(s...
# 2  https://api.census.gov/data/2019/acs/acs5/vari...
# 3  https://api.census.gov/data/2019/acs/acs5/vari...
# 4  STATEFP(string,2)|COUNTYFP(string,3)|TRACTCE(s...
# 5  https://api.census.gov/data/2020/acs/acs5/vari...
# 6  https://api.census.gov/data/2020/acs/acs5/vari...
# 7  STATEFP(string,2)|COUNTYFP(string,3)|TRACTCE(s...
# 8  https://api.census.gov/data/2021/acs/acs5/vari...
# 9  https://api.census.gov/data/2021/acs/acs5/vari...
#
#                                    ETL Documentation  \
# 0  Direct download as ESRI json from ESRI service...
# 1                       ogr2ogr shapefile to postGIS
# 2  The custom function acs_customgregate is given...
# 3  The custom function acs_customgregate is given...
# 4                       ogr2ogr shapefile to postGIS
# 5  The custom function acs_customgregate is given...
# 6  The custom function acs_customgregate is given...
# 7                       ogr2ogr shapefile to postGIS
# 8  The custom function acs_customgregate is given...
# 9  The custom function acs_customgregate is given...
#
#                                                Notes  \
# 0                                                NaN
# 1                                                NaN
# 2  please use this as a template for all ACS esti...
# 3                update using 2019 DVMT ACS as model
# 4                                                NaN
# 5                update using 2019 DVMT ACS as model
# 6                update using 2019 DVMT ACS as model
# 7                                                NaN
# 8                update using 2019 DVMT ACS as model
# 9                update using 2019 DVMT ACS as model
#
#                                                 TODO
# 0  update to reflect Miami only\ninclude other ci...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  update to reflect Florida only\nimprove column...
# 6  update to reflect Florida only\nimprove column...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 66 columns]

# %%
# Select specific columns
selected_columns = ['Title', 'Geometry', 'Extent']
new_df = df[selected_columns]

fdf = new_df[new_df['Geometry'] != '--']  # Replace 'col1' with your actual column name

fdf2 = fdf.dropna(subset=['Extent'], inplace=False)  # Get the result without modifying df
fdf2 = fdf2.copy()  # Create a copy to avoid SettingWithCopyWarning

# %%
fdf2.head(30)
# Out:
#                                                 Title Geometry  \
# 0   Miami-Dade Home Owner's Loan Corporation (HOLC...  polygon
# 1                          2019 Florida Census Tracts  polygon
# 4                2020 Florida Census Tracts - Florida  polygon
# 7                2021 Florida Census Tracts - Florida  polygon
# 10         2021 Florida Census Block Groups - Florida  polygon
# 12                 Florida State Funded Cleanup Sites    point
# 15  TIGER/Line Shapefile, 2022, state, Florida, Cu...  polygon
# 16     TIGER/Line Shapefile, 2022, US, Current County  polygon
# 22                         Miami-Dade Park Facilities    point
# 23                         Miami-Dade Police Stations    point
# 24                               Miami-Dade Hospitals    point
# 25      Miami-Dade Federally Qualified Health Centers    point
# 26                           Miami-Dade Fire Stations    point
# 27                     Miami-Dade Municipal LIbraries    point
# 28                        Miami-Dade County Libraries    point
# 29                         Miami-Dade Charter Schools    point
# 30                                Miami-Dade Colleges    point
# 31                         Miami-Dade Private Schools    point
# 32                          Miami-Dade Public Schools    point
# 33                     Miami-Dade Property Point View    point
# 34                Miami-Dade Community Health Centers    point
# 35                     Miami-Dade Commercial Property    point
# 36                               Miami-Dade Metrorail     line
# 37                      Miami-Dade Metrorail Stations    point
# 38                              Miami-Dade Metromover     line
# 39                     Miami-Dade Metromover Stations    point
# 40                               Miami-Dade Bus Stops    point
# 41                              Miami-Dade Bike Lanes     line
# 42                                Florida US Highways     line
# 63             Miami-Dade Qualified Opportunity Zones  polygon
#
#                                                Extent
# 0   -122.767506653|25.705373207|-70.949200532|47.7...
# 1           31.000968|24.396308|-87.634896|-79.974306
# 4           31.000968|24.396308|-87.634896|-79.974306
# 7           31.000968|24.396308|-87.634896|-79.974306
# 10          31.000968|24.396308|-87.634896|-79.974306
# 12  -115000.00244509568|-115000.0053524822|1014999...
# 15          -87.634896|31.000968|-79.974306|24.396308
# 16        -179.231086|-14.601813|179.859681|71.439786
# 22  -8990813.946|2924852.2194|-8918818.8245|299584...
# 23  -8952639.3862|2946045.317|-8922810.83|2989189....
# 24  -8960265.2705|2927290.3219|-8920945.0237|29953...
# 25  -8961487.8184|2927362.3086|-8920255.8356|29920...
# 26  -8959341.3726|2930803.5471|-8919271.5634|29947...
# 27  -8942567.8129|2966265.6874|-8919113.6925|29901...
# 28  -8954722.9202|2938063.4767|-8918997.2555|29941...
# 29  -8960782.9701|2929916.7558|-8919298.2245|29928...
# 30  -8961336.3137|2934145.8381|-8920287.9684|29945...
# 31  -8994961.3103|2930756.0944|-8919298.0286|29955...
# 32  -8961929.9518|2930076.2662|-8919271.0569|29955...
# 33  -9002729.5287|2893671.97230001|-8918780.1333|2...
# 34  -8976260.5448|2913609.9319|-8918917.2292|29959...
# 35  -8976260.5448|2913609.9319|-8918917.2292|29959...
# 36  -8941488.9338|2960158.102|-8927316.9564|298000...
# 37  -8941598.6193|2960119.1879|-8927318.3812|29799...
# 38  -8927407.3469|2969430.6499|-8926325.3762|29730...
# 39  -8927388.6424|2969433.8745|-8926412.2917|29730...
# 40  -9025308.5242|2840919.428|-8918938.0475|301433...
# 41  -8959587.4876|2929462.8399|-8919018.9017|29959...
# 42  -119240.19616517|2715402.68066709|594411.50011...
# 63  -8961393.5314|2929033.1695|-8919660.1774|29959...
